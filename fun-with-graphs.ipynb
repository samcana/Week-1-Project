# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import re

# %%
usa_total_jobs = usa['loc_code'].value_counts().rename_axis('State').reset_index(name='counts')
usa_total_jobs.columns = ['State', 'Number of Jobs']
print(usa_total_jobs)
usa_total_jobs.dtypes
# Out:
#   State  Number of Jobs
# 0    CA            2152
# 1    MA            1323
# 2    WA             935
# 3    NY             926
# 4    IL             471
# 5    DC             340
# 6    GA             269
# 7    CO             251
# 8    TX             218
# 9    NJ              68
# State             object
# Number of Jobs     int64
# dtype: object

# %%
#usa_total_jobs.columns = ['State', 'Number of Jobs']
usa_total_jobs
usa_total_jobs.reset_index()
usa_total_jobs.columns = ['Index','State', 'Number of Jobs']

# %%
usa_total_jobs
# Out:
# CA    2152
# MA    1323
# WA     935
# NY     926
# IL     471
# DC     340
# GA     269
# CO     251
# TX     218
# NJ      68
# Name: loc_code, dtype: int64

# %%
usa_total_jobs_pop = usa_total_jobs.assign(Population = ['39368', '6893', '7694', '19337', '12588', '713', '10710', '5808', '29361', '8882'])
usa_total_jobs_pop['Population'] = usa_total_jobs_pop['Population'].astype(int)
usa_total_jobs_pop
# Out:
#   State  Number of Jobs  Population
# 0    CA            2152       39368
# 1    MA            1323        6893
# 2    WA             935        7694
# 3    NY             926       19337
# 4    IL             471       12588
# 5    DC             340         713
# 6    GA             269       10710
# 7    CO             251        5808
# 8    TX             218       29361
# 9    NJ              68        8882

# %%
usa_total_jobs_pop.dtypes
# Out:
# State             object
# Number of Jobs     int64
# Population         int64
# dtype: object

# %%
usa_total_jobs_pop.set_index("State",drop=True,inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
#usa_total_jobs_pop.set_index("State",drop=True,inplace=True)
fig, ax1 = plt.subplots(figsize=(15, 10))
ax2 = ax1.twinx()
usa_total_jobs_pop["Population"].plot(kind='bar', color='y', ax=ax1)
usa_total_jobs_pop["Number of Jobs"].plot(kind='line', marker='d', ax=ax2)
ax1.yaxis.tick_left()
ax2.yaxis.tick_right()
#ax1.set_xticklabels("State", rotation=0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
#usa_total_jobs_pop.set_index("State",drop=True,inplace=True)
fig, ax1 = plt.subplots(figsize=(15, 10))
ax2 = ax1.twinx()
usa_total_jobs_pop['Population'].plot(kind='bar', color='y', ax=ax1)
usa_total_jobs_pop['Number of Jobs'].plot(kind='line', marker='d', ax=ax2)
ax1.yaxis.tick_right()
ax2.yaxis.tick_left()
#ax1.set_xticklabels("State", rotation=0)

# %%
import pandas as pd

usa_total_jobs = pd.DataFrame()

usa_total_jobs.insert(2, "population", [39368, 6893, 7694, 19337, 12588, 713, 10710, 5808, 29361, 8882], True )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-8f69fdaca429> in <module>
#       3 usa_total_jobs = pd.DataFrame()
#       4
# ----> 5 usa_total_jobs.insert(2, "population", [39368, 6893, 7694, 19337, 12588, 713, 10710, 5808, 29361, 8882], True )
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1218             self._blknos = np.append(self._blknos, len(self.blocks))
# ...
